# %% [markdown]
# <a href="https://colab.research.google.com/github/haleshgowda77/FUTURE_DS_03/blob/main/Task03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/bank-additional-full.csv",sep=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
total = df.shape[0]
print("Total Contacted:",total)
# Out:
# Total Contacted: 41188

# %%
df['y'].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
converted = df[df['y'] == 'yes'].shape[0]
print(converted)
# Out:
# 4640

# %%
drop_off = total - converted
print(drop_off)
# Out:
# 36548

# %%
conversation_rate = (5289/45211) * 100
print('conversation_rate:',conversation_rate)
# Out:
# conversation_rate: 11.698480458295547

# %% [markdown]
# # Insigths
# ---
# * The overall conversion rate is approximately 11.7%
# * This indicates only a small percentage of contacted users became customers

# %%
stages = ['contacted','converted']
values = [45211,5289]
plt.figure()
plt.bar(stages,values)
plt.title("Marketing Funnel")
plt.xlabel("Stages")
plt.ylabel("Number of Users")
plt.savefig("Marketing Funnel.png")
plt.show()

# %%
from google.colab import files
files.download("Marketing Funnel.png")

# %% [markdown]
# # Insights
# ---
# * Out of 45,211 users contacted, only 5,289 converted
# * The conversion rate is approximately 11.7%
# * A large drop-off is observed between contacted and converted users
# * Majority of users (around 88%) did not convert
# * The marketing campaign shows low conversion efficiency

# %%
df.groupby('job')['y'].value_counts().unstack()
# Out:
# y                no   yes
# job
# admin.         9070  1352
# blue-collar    8616   638
# entrepreneur   1332   124
# housemaid       954   106
# management     2596   328
# retired        1286   434
# self-employed  1272   149
# services       3646   323
# student         600   275
# technician     6013   730
# unemployed      870   144
# unknown         293    37

# %% [markdown]
# # Business Questions Analysis
#
# **1. Where are users dropping off in the funnel?**
#
# A major drop-off occurs between the contacted and converted stages. Out of 45,211 users contacted, only 5,289 converted, meaning 39,922 users dropped off. This indicates a significant loss in the funnel.
#
# **2. Which channels bring high-quality leads?**
#
# Based on the analysis of job categories, certain groups show higher conversions compared to others. These segments can be considered as high-quality leads and should be targeted more.
#
# **3. Which stages need optimization?**
#
# The conversion stage needs the most optimization, as there is a high drop-off between contacted users and converted customers. Efforts should focus on improving this stage.
#
# **Compare Performance Across Segments**
#
# Performance was compared across different job categories. Some segments showed higher conversion rates, indicating better customer potential.
#
# **Recommendations to Improve Conversions**
#
# * Focus on high-performing customer segments
# * Improve communication and engagement strategies
# * Use personalized marketing approaches
# * Optimize targeting to reduce drop-offs
